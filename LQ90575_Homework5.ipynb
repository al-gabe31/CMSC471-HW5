# %% [markdown]
# # Question 2

# %%
import importlib
import functions as functions
from functions import *
importlib.reload(functions)

scaled_values = get_scaled_values('cars.csv')

# Prints the first 5 scaled values of each of the 10 features
print_scaled_values(scaled_values, ['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'])
print("")
report_mean_and_variance('cars.csv', ['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'])
make_mpg_scaled_wt_sp('cars.csv')

print("EXITED WITHOUT ERROR")
# Out:
# cyl            disp           hp             drat           wt             qsec           vs             am             gear           carb
# -0.106668      -0.57975       -0.543655      0.576594       -0.620167      -0.789601      -0.881917      1.208941       0.430331       0.708088
# -0.106668      -0.57975       -0.543655      0.576594       -0.355382      -0.471202      -0.881917      1.208941       0.430331       0.708088
# -1.244457      -1.006026      -0.79557       0.481584       -0.931678      0.432823       1.133893       1.208941       0.430331       -1.080766
# -0.106668      0.223615       -0.543655      -0.981576      -0.002336      0.904736       1.133893       -0.82717       -0.946729      -1.080766
# 1.031121       1.059772       0.41955        -0.848562      0.231297       -0.471202      -0.881917      -0.82717       -0.946729      -0.484481
#
#        cyl            disp           hp             drat           wt             qsec           vs             am             gear           carb
# MEAN   6.1875         230.721875     146.6875       3.596562       3.21725        17.84875       0.4375         0.40625        3.6875         2.8125
# VAR    3.089844       14880.774834   4553.964844    0.276948       0.927461       3.09338        0.246094       0.241211       0.527344       2.8125
# EXITED WITHOUT ERROR

# %%
# How to create a scatter plot and linear regression
# Source: https://www.w3schools.com/python/python_ml_linear_regression.asp

import matplotlib.pyplot as plt
from scipy import stats # You might need to do "python -m pip install scipy" if you haven't already

# Data for the scatter plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y) # Gets important values for the linear regression (you really only need slope and intercept for this one)

def myfunc(x): # Returns the y-estimate based on an x-value for the linear regression
    return slope * x + intercept

mymodel = list(map(myfunc,x)) # y-values of the linear regression

plt.scatter(x, y) # Plots arrays x and y into a scatter plot
plt.plot(x, mymodel) # Plots the linear regression
plt.show()

# %%
# How to get the variance of a list
# Source: https://stackoverflow.com/questions/35583302/how-can-i-calculate-the-variance-of-a-list-in-python

import numpy as np

results = [-14.82381293, -0.29423447, -13.56067979, -1.6288903, -0.31632439,
          0.53459687, -1.34069996, -1.61042692, -4.03220519, -0.24332097]

print(np.var(results)) # Prints the variance of the results array
# Out:
# 28.822364260579157

# %%
# How to read a CSV file
# Source: https://docs.python.org/3/library/csv.html

import csv

# This is where all data will be stored
mpg = []
cyl = []
disp = []
hp = []
drat = []
wt = []
qsec = []
vs = []
am = []
gear = []
carb = []

with open('cars.csv', newline='') as csvfile:
    line = csv.reader(csvfile, delimiter=',')

    line_num = 0
    for row in line:
        if line_num > 0: # We ignore the first line since that's just the header
            # Takes all values from the csv and puts them into their respective array
            mpg.append(float(row[0]))
            cyl.append(float(row[1]))
            disp.append(float(row[2]))
            hp.append(float(row[3]))
            drat.append(float(row[4]))
            wt.append(float(row[5]))
            qsec.append(float(row[6]))
            vs.append(float(row[7]))
            am.append(float(row[8]))
            gear.append(float(row[9]))
            carb.append(float(row[10]))
        line_num += 1

# Prints data from all 11 arrays
for i in range(len(mpg)):
    print(f"{mpg[i]} {cyl[i]} {disp[i]} {hp[i]} {drat[i]} {wt[i]} {qsec[i]} {vs[i]} {am[i]} {gear[i]} {carb[i]}")
# Out:
# 21.0 6.0 160.0 110.0 3.9 2.62 16.46 0.0 1.0 4.0 4.0
# 21.0 6.0 160.0 110.0 3.9 2.875 17.02 0.0 1.0 4.0 4.0
# 22.8 4.0 108.0 93.0 3.85 2.32 18.61 1.0 1.0 4.0 1.0
# 21.4 6.0 258.0 110.0 3.08 3.215 19.44 1.0 0.0 3.0 1.0
# 18.7 8.0 360.0 175.0 3.15 3.44 17.02 0.0 0.0 3.0 2.0
# 18.1 6.0 225.0 105.0 2.76 3.46 20.22 1.0 0.0 3.0 1.0
# 14.3 8.0 360.0 245.0 3.21 3.57 15.84 0.0 0.0 3.0 4.0
# 24.4 4.0 146.7 62.0 3.69 3.19 20.0 1.0 0.0 4.0 2.0
# 22.8 4.0 140.8 95.0 3.92 3.15 22.9 1.0 0.0 4.0 2.0
# 19.2 6.0 167.6 123.0 3.92 3.44 18.3 1.0 0.0 4.0 4.0
# 17.8 6.0 167.6 123.0 3.92 3.44 18.9 1.0 0.0 4.0 4.0
# 16.4 8.0 275.8 180.0 3.07 4.07 17.4 0.0 0.0 3.0 3.0
# 17.3 8.0 275.8 180.0 3.07 3.73 17.6 0.0 0.0 3.0 3.0
# 15.2 8.0 275.8 180.0 3.07 3.78 18.0 0.0 0.0 3.0 3.0
# 10.4 8.0 472.0 205.0 2.93 5.25 17.98 0.0 0.0 3.0 4.0
# 10.4 8.0 460.0 215.0 3.0 5.424 17.82 0.0 0.0 3.0 4.0
# 14.7 8.0 440.0 230.0 3.23 5.345 17.42 0.0 0.0 3.0 4.0
# 32.4 4.0 78.7 66.0 4.08 2.2 19.47 1.0 1.0 4.0 1.0
# 30.4 4.0 75.7 52.0 4.93 1.615 18.52 1.0 1.0 4.0 2.0
# 33.9 4.0 71.1 65.0 4.22 1.835 19.9 1.0 1.0 4.0 1.0
# 21.5 4.0 120.1 97.0 3.7 2.465 20.01 1.0 0.0 3.0 1.0
# 15.5 8.0 318.0 150.0 2.76 3.52 16.87 0.0 0.0 3.0 2.0
# 15.2 8.0 304.0 150.0 3.15 3.435 17.3 0.0 0.0 3.0 2.0
# 13.3 8.0 350.0 245.0 3.73 3.84 15.41 0.0 0.0 3.0 4.0
# 19.2 8.0 400.0 175.0 3.08 3.845 17.05 0.0 0.0 3.0 2.0
# 27.3 4.0 79.0 66.0 4.08 1.935 18.9 1.0 1.0 4.0 1.0
# 26.0 4.0 120.3 91.0 4.43 2.14 16.7 0.0 1.0 5.0 2.0
# 30.4 4.0 95.1 113.0 3.77 1.513 16.9 1.0 1.0 5.0 2.0
# 15.8 8.0 351.0 264.0 4.22 3.17 14.5 0.0 1.0 5.0 4.0
# 19.7 6.0 145.0 175.0 3.62 2.77 15.5 0.0 1.0 5.0 6.0
# 15.0 8.0 301.0 335.0 3.54 3.57 14.6 0.0 1.0 5.0 8.0
# 21.4 4.0 121.0 109.0 4.11 2.78 18.6 1.0 1.0 4.0 2.0
